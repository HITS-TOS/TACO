# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [15, 10]
plt.rcParams["figure.autolayout"] = True

df = pd.read_csv('../benchmarks/benchmark3.csv', index_col=0)
print(df.T)

df.T.plot.bar()
plt.xlabel('TACO module')
plt.ylabel('Time / s')
plt.show()
# Out:
# dataset          1296068  9332840
# filter             1.263    2.195
# pds                1.865    1.973
# numax             16.788   14.738
# backgound_fit     32.074   41.055
# find_peaks        26.393   33.754
# peaksMLE          34.187   47.812
# peakBagModeId02    4.476    4.732
# find_peaks.1      35.292   35.992
# peaksMLE.1        56.037   48.878
# peaksMLE.2        23.064   59.947
